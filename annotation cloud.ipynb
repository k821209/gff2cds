# %%
# %matplotlib inline
from os import path
from wordcloud import WordCloud
import pandas as pd 

file_annot = 'new_gene.fa.bp.na1.uniprot-all.fasta.out7.annot'
df_annot   = pd.read_csv(file_annot,sep='\t')

# %%
df_annot.head()
# Out:
#    Unnamed: 0                   0                     1      2    3    4   5  \
# 0           0   STRG.28.2|m.13357  sp|P16423|POLR_DROME  25.61  453  284  12
# 1           1   STRG.28.2|m.13357  sp|P16423|POLR_DROME  25.61  453  284  12
# 2           6  STRG.184.1|m.26632  sp|Q9VMJ7|KDM5_DROME  39.53   86   46   2
# 3           7  STRG.185.1|m.15264    sp|Q66H30|GIN1_RAT  28.14  199  135   5
# 4          26   STRG.261.1|m.2566    sp|O04279|GPA2_PEA  27.91   86   53   1
#
#       6     7    8    9            10     11  \
# 0  1238  1685  354  758  4.000000e-22  108.0
# 1  1238  1685  354  758  4.000000e-22  108.0
# 2   191   270  445  530  6.000000e-12   72.0
# 3    37   230   15  210  2.000000e-16   81.6
# 4    38   114  146  231  6.000000e-03   40.0
#
#                                           annotation
# 0  Retrovirus-related Pol polyprotein from type-2...
# 1  Retrovirus-related Pol polyprotein from type-2...
# 2  Lysine-specific demethylase lid OS=Drosophila ...
# ...

# %%
text
# Out:
# 'Retrovirus-related Pol polyprotein from type-2 retrotransposable element R2DM OS=Drosophila melanogaster GN=pol PE=3 SV=1 Retrovirus-related Pol polyprotein from type-2 retrotransposable element R2DM OS=Drosophila melanogaster GN=pol PE=3 SV=1 Lysine-specific demethylase lid OS=Drosophila melanogaster GN=lid PE=1 SV=1 Gypsy retrotransposon integrase-like protein 1 OS=Rattus norvegicus GN=GIN1 PE=2 SV=1 Guanine nucleotide-binding protein alpha-2 subunit OS=Pisum sativum GN=GPA2 PE=2 SV=1 Transposon TX1 uncharacterized 149 kDa protein OS=Xenopus laevis PE=3 SV=1 Growth arrest and DNA damage-inducible proteins-interacting protein 1 OS=Rattus norvegicus GN=Gadd45gip1 PE=2 SV=2 E3 ubiquitin-protein ligase RNF185 OS=Mus musculus GN=Rnf185 PE=2 SV=1 DExH-box ATP-dependent RNA helicase DExH14 OS=Arabidopsis thaliana GN=At5g61140 PE=2 SV=1 DExH-box ATP-dependent RNA helicase DExH14 OS=Arabidopsis thaliana GN=At5g61140 PE=2 SV=1 Focal adhesion kinase 1 OS=Mus musculus GN=Ptk2 PE=1 SV=3 Probab
# ...

# %%
text = ' '.join(x.split('=')[0][:-2] for x in df_annot['annotation'].values)

# Generate a word cloud image
wordcloud = WordCloud(width=1600,height=1000,stopwords=["protein","homolog","kDa","related","Probable"]).generate(text)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
'''# take relative word frequencies into account, lower max_font_size
wordcloud = WordCloud(max_font_size=40, relative_scaling=.5).generate(text)
plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig("annotation.png",dpi=500)'''
# Out:
# '# take relative word frequencies into account, lower max_font_size\nwordcloud = WordCloud(max_font_size=40, relative_scaling=.5).generate(text)\nplt.figure()\nplt.imshow(wordcloud)\nplt.axis("off")\nplt.savefig("annotation.png",dpi=500)'

# %%
plt.savefig("annotation.png",dpi=500)
